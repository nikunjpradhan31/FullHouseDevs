# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.yaml")
results = model.train(data="./data/data.yaml", epochs=10, device='cpu')
# Out:
# Ultralytics 8.4.21  Python-3.12.12 torch-2.5.1+cu121 CPU (Intel Core i9-9900K 3.60GHz)
# ...

# %%
results = model.val(device='cpu')
results = model("./data/valid/images/000507247_jpg.rf.6a57e870859691da0fcd008760344bcc.jpg") # single image inference
success = model.export(format="onnx")
print([x for x in results])
# Out:
# Ultralytics 8.4.21  Python-3.12.12 torch-2.5.1+cu121 CPU (Intel Core i9-9900K 3.60GHz)
# YOLOv8n summary (fused): 73 layers, 3,015,788 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 158.629.0 MB/s, size: 33.1 KB)
# val: Scanning C:\Users\Chris\.vscode\Repositories\FullHouseDevs\data\valid\labels.cache... 4000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4000/4000  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 250/250 1.0s/it 4:18<1.0s
#                    all       4000      15159      0.291      0.565      0.335      0.274
#                    10c        180        282      0.357      0.728      0.441      0.347
#                    10d        188        290      0.274      0.417      0.255      0.202
#                    10h        201        322      0.346      0.661      0.424      0.334
# ...
